# %% [markdown]
# # Frictionshift\n\nPhase 2 notebook walkthrough.

# %%
import pandas as pd\nfrom frictionshift import FrictionshiftCalculator\n

# %%
df = pd.read_csv("frictionshift_dataset.csv")\ndf.head()\n

# %%
calc = FrictionshiftCalculator()\nresult = calc.calculate_frictionshift(df)\nresult.head()\n

# %%
result["frictionshift_index"].describe()\n

# %%
result.groupby("frictionshift_band").size()\n

# %%
result["frictionshift_index"].hist(bins=20)\n

# %% [markdown]
# Interpretation: `Frictionshift` index is now ready for stress testing.
